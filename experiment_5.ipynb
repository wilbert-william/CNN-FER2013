# %% [markdown]
# # 1) Import library yang dibutuhkan

# %%
import pickle # Used to save history of training progress
import random
import datetime # Getting timestamp: Used to get date for labelling model using the function ModelCheckpoint
import numpy as np # used for most mathematical operations
import pandas as pd # Used to create a dataframe from detaset for the model
import matplotlib.pyplot as plt # Use for visualization by plotting data or data points
import tensorflow as tf

from keras.models import Sequential
from keras.models import load_model # Used to load pretrained model for testing
from keras.utils import to_categorical # used to label the data
from keras.callbacks import ModelCheckpoint # Used to save best model weights during training process
from sklearn.metrics import confusion_matrix
from tensorflow.keras.optimizers import Adam # Model optimizer: Learning rate of 1e-5 is used
from sklearn.model_selection import train_test_split # Used to split data into Training, Validation & Testing
from keras.preprocessing.image import ImageDataGenerator # Used for data augmentation: mainly to reduce within class imbalance to improve accurracy of the model
from keras.callbacks import EarlyStopping, ReduceLROnPlateau # Early stopping helps to stop training when model is no longer learning
from keras.layers import Conv2D, AveragePooling2D, Flatten, Dense, Dropout, Activation # Functions used to build the CNN architecture of the model
# Out:
# WARNING:tensorflow:From c:\Users\wilbe\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  0

# %% [markdown]
# # 2) Mendefinisikan Fungsi

# %% [markdown]
# Berikut adalah penjelasan untuk setiap fungsi yang diberikan:
#
# 1. **getDataCount(emotion_map=None, data=None):**
#    - Fungsi ini menghitung jumlah sampel untuk setiap kategori emosi dalam dataset.
#    - `emotion_map`: Pemetaan label emosi ke dalam nama emosi.
#    - `data`: DataFrame yang berisi data emosi.
#
# 2. **barplot(data=None, emotion_map=None, plt=None, titleType='Emotions'):**
#    - Fungsi ini membuat bar plot untuk distribusi kelas dalam dataset.
#    - `data`: DataFrame yang berisi data emosi.
#    - `emotion_map`: Pemetaan label emosi ke dalam nama emosi.
#    - `plt`: Objek matplotlib untuk membuat plot.
#    - `titleType`: Tipe judul untuk plot.
#
# 3. **plotDatasetSamples(file_path=None, emotion_map=None ,max_num_plot=10):**
#    - Fungsi ini memvisualisasikan sampel dataset dengan plot grid.
#    - `file_path`: Path ke file CSV yang berisi data gambar.
#    - `emotion_map`: Pemetaan label emosi ke dalam nama emosi.
#    - `max_num_plot`: Jumlah maksimum sampel yang akan ditampilkan.
#
# 4. **downSampleData(data=None, emotion_map=None):**
#    - Fungsi ini melakukan downsampling pada dataset untuk menyeimbangkan kelas.
#    - `data`: DataFrame yang berisi data emosi.
#    - `emotion_map`: Pemetaan label emosi ke dalam nama emosi.
#
# 5. **preProcess_augment_oversample(file_path=None, datagen=None, target_samples=None, imbalance_threshold=None):**
#    - Fungsi ini melakukan pre-processing, augmentasi data, dan oversampling pada dataset gambar.
#    - `file_path`: Path ke file CSV yang berisi data gambar.
#    - `datagen`: Objek ImageDataGenerator untuk augmentasi data.
#    - `target_samples`: Jumlah target sampel setelah augmentasi.
#    - `imbalance_threshold`: Ambang batas ketidakseimbangan kelas untuk oversampling.
#
# 6. **create_CNN_model(input_shape=None):**
#    - Fungsi ini mendefinisikan arsitektur model CNN menggunakan Keras Sequential.
#    - `input_shape`: Bentuk input untuk model.
#
# 7. **plotModelHistory(history=None, plt=None):**
#    - Fungsi ini memplot grafik histori pelatihan model (akurasi dan loss) dari objek `history` Keras.
#    - `history`: Objek histori dari proses pelatihan model.
#    - `plt`: Objek matplotlib untuk membuat plot.
#
# 8. **plotLoadedModelHistory(history_dict=None, plt=None):**
#    - Fungsi ini memplot grafik histori pelatihan model (akurasi dan loss) dari dictionary `history_dict`.
#    - `history_dict`: Dictionary yang berisi histori dari proses pelatihan model.
#    - `plt`: Objek matplotlib untuk membuat plot.
#
# 9. **plotConfusionMatrix(model=None, X_test=None, y_test=None, emotion_map=None, plt=None, np=None):**
#    - Fungsi ini memplot matriks kebingungan (confusion matrix) dari model klasifikasi.
#    - `model`: Model yang telah dilatih.
#    - `X_test`: Data uji untuk evaluasi model.
#    - `y_test`: Label yang sebenarnya dari data uji.
#    - `emotion_map`: Pemetaan label emosi ke dalam nama emosi.
#    - `plt`: Objek matplotlib untuk membuat plot.
#    - `np`: Modul NumPy untuk operasi numerik.
#
# 10. **plotPredictions(X_test=None, y_test=None,  model=None, plt=None, emotion_map=None, max_num_plot=10 ):**
#     - Fungsi ini memplot prediksi model pada beberapa sampel data uji.
#     - `X_test`: Data uji untuk evaluasi model.
#     - `y_test`: Label yang sebenarnya dari data uji.
#     - `model`: Model yang telah dilatih.
#     - `plt`: Objek matplotlib untuk membuat plot.
#     - `emotion_map`: Pemetaan label emosi ke dalam nama emosi.
#     - `max_num_plot`: Jumlah maksimum sampel yang akan ditampilkan.
#
# 11. **sampleAugmentationPlotOnly(X_train=None):**
#     - Fungsi ini memvisualisasikan contoh augmentasi data untuk gambar.
#     - `X_train`: Data latih yang digunakan untuk membuat contoh augmentasi.
#
# Setiap fungsi ini mengambil argumen yang sesuai untuk memanipulasi dan memvisualisasikan data serta model yang terlibat dalam analisis emosi berbasis gambar.

# %%
def getDataCount(emotion_map=None, data=None, ):
  emotion_counts = data['emotion'].value_counts(sort=False).reset_index()
  emotion_counts.columns = ['emotion', 'number']
  emotion_counts['emotion'] = emotion_counts['emotion'].map(emotion_map)
  return emotion_counts

#*******************************************************************************
def barplot(data=None, emotion_map=None, plt=None, titleType='Emotions'):
    emotion_counts = getDataCount(emotion_map, data=data)
    # print(emotion_counts)
    colors = ['red', 'green', 'blue', 'orange', 'purple', 'cyan', 'magenta']
    plt.figure(figsize=(8, 6))
    bars = plt.bar(emotion_counts['emotion'], emotion_counts['number'], color=colors)
    plt.title('Class Distribution Of '+ titleType)
    plt.xlabel('Emotions')
    plt.ylabel('Number Of Samples')
    plt.xticks(rotation=45)

    for bar, count in zip(bars, emotion_counts['number']):
        plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), count,
                ha='center', va='bottom', fontsize=8, color='black')

    plt.tight_layout()
    plt.show()

#*******************************************************************************
def plotDatasetSamples(file_path=None, emotion_map=None ,max_num_plot=10):
    if max_num_plot % 3 != 0:
        print(f"'max_num_plot' cannot be odd. Defaulting to max_num_plot = {max_num_plot - 1}")
        max_num_plot = max_num_plot - 1

    df = pd.read_csv(file_path)
    df['pixels'] = df['pixels'].apply(lambda x: [int(p) for p in x.split()])
    df['pixels'] = df['pixels'].apply(lambda x: np.array(x).reshape(48, 48, 1))
    samples = df.sample(max_num_plot)
    samples['emotion_label'] = samples['emotion'].map(emotion_map)

    # Plotting the pixel data
    plt.figure(figsize=(12, 6))
    for i in range(max_num_plot):
        plt.subplot(3, 5, i + 1)
        plt.imshow(samples['pixels'].values[i].reshape(48, 48), cmap='gray')
        plt.title(f"{samples['emotion_label'].values[i]}")
        plt.axis('off')

    plt.tight_layout()
    plt.show()

#*******************************************************************************
def downSampleData(data=None, emotion_map=None):
    # print('----------------------------------------------\n',data)
    min_count = getDataCount(emotion_map, data=data)['number'].min()
    grouped = data.groupby('emotion')
    down_sampled = grouped.apply(lambda x: x.sample(min_count))
    down_sampled.reset_index(drop=True, inplace=True)
    # print(down_sampled)
    return down_sampled

#*******************************************************************************
def preProcess(file_path=None):
    df = pd.read_csv(file_path)
    df['pixels'] = df['pixels'].apply(lambda x: [int(p) for p in x.split()])  # Convert strings to lists of integers
    df['pixels'] = df['pixels'].apply(lambda x: np.array(x).reshape(48, 48, 1))  # Reshape to 48x48x1
    df['pixels'] = df['pixels'] / 255.0  # Normalisation

    data = np.array(df['pixels'].tolist())
    labels = to_categorical(df['emotion'])

    return data, labels
#*******************************************************************************
def create_CNN_model(input_shape=None):
    if input_shape is None:
        input_shape = (48, 48, 1)

    model = Sequential()

    # Convolutional layers
    model.add(Conv2D(32, (3, 3), padding='same', input_shape=input_shape))
    model.add(Activation('relu'))
    
    model.add(Conv2D(64, (3, 3)))
    model.add(Activation('relu'))
    model.add(AveragePooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(128, (3, 3), padding='same'))
    model.add(Activation('relu'))
    model.add(Conv2D(128, (3, 3)))
    model.add(Activation('relu'))
    model.add(AveragePooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

    # Flatten layer to transition from convolutional to fully connected layers
    model.add(Flatten())

    # Fully connected layers
    model.add(Dense(128))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))

    # Output layer
    model.add(Dense(7))
    model.add(Activation('softmax'))

    return model

#*******************************************************************************
def plotModelHistory(history=None, plt=None):
    fig, axs = plt.subplots(1,2,figsize=(15,5))
    # history for accuracy
    axs[0].plot(history.history['accuracy'])
    axs[0].plot(history.history['val_accuracy'])
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].legend(['train', 'validate'], loc='upper left')
    axs[0].grid(True)
    # history for loss
    axs[1].plot(history.history['loss'])
    axs[1].plot(history.history['val_loss'])
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].legend(['train', 'validate'], loc='upper left')
    axs[1].grid(True)
    plt.show()

#*******************************************************************************
def plotLoadedModelHistory(history_dict=None, plt=None):
    fig, axs = plt.subplots(1, 2, figsize=(15, 5))
    # history for accuracy
    axs[0].plot(history_dict['accuracy'])
    axs[0].plot(history_dict['val_accuracy'])
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].legend(['Train', 'Validation'], loc='upper left')
    axs[0].grid(True)

    # history for loss
    axs[1].plot(history_dict['loss'])
    axs[1].plot(history_dict['val_loss'])
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].legend(['Train', 'Validation'], loc='upper left')
    axs[1].grid(True)
    plt.show()

#*********************************************************************************
def plotConfusionMatrix(model=None, X_test=None, y_test=None, emotion_map=None, plt=None, np=None):
  # predictions of model
  y_pred = model.predict(X_test)
  y_pred_classes = np.argmax(y_pred, axis=1)

  # Compute confusion matrix
  conf_matrix = confusion_matrix(np.argmax(y_test, axis=1), y_pred_classes)

  # Plot confusion matrix using Matplotlib
  plt.figure(figsize=(8, 6))
  plt.imshow(conf_matrix, interpolation='nearest', cmap='Blues')
  plt.colorbar()
  # Set tick marks and labels
  tick_marks = np.arange(len(emotion_map))
  plt.xticks(tick_marks, emotion_map.values(), rotation=45)
  plt.yticks(tick_marks, emotion_map.values())

  for i in range(len(emotion_map)):
      for j in range(len(emotion_map)):
          plt.text(j, i, conf_matrix[i, j], ha='center', va='center', color='black')

  plt.xlabel('Predicted')
  plt.ylabel('True')
  plt.title('Confusion Matrix')

  plt.tight_layout()
  plt.show()

#*******************************************************************************
def plotPredictions(X_test=None, y_test=None,  model=None, plt=None, emotion_map=None, max_num_plot=10 ):
  if max_num_plot % 3 != 0:
    print(f"'max_num_plot' cannot be old. Defaulting to max_num_plot= {max_num_plot} -1 = {max_num_plot-1}")
    max_num_plot = max_num_plot- 1

  predictions = model.predict(X_test)
  predicted_labels = np.argmax(predictions, axis=1)

  # Calculate accuracy
  correct_predictions = np.equal(predicted_labels, np.argmax(y_test, axis=1))
  accuracy = np.mean(correct_predictions)
  print(f"Test Accuracy: {accuracy * 100:.2f}%")

  # Create a list of emotions from the predicted labels using the emotion_map
  predicted_emotions = [emotion_map[label] for label in predicted_labels]
  actual_emotions = [emotion_map[label] for label in np.argmax(y_test, axis=1)]


  plt.figure(figsize=(12, 6))
  for i in range(1,max_num_plot+1):
      plt.subplot(3, max_num_plot // 3, i)
      plt.imshow(X_test[i].reshape(48, 48), cmap='gray')
      plt.title(f"Actual: {actual_emotions[i]}\nPredicted: {predicted_emotions[i]}",fontsize=8)
      plt.axis('off')

  plt.tight_layout()
  plt.show()

#*******************************************************************************
def sampleAugmentationPlotOnly(X_train=None):
  rotate_datagen = ImageDataGenerator(vertical_flip=True, fill_mode='nearest')  # Rotate images by up to angle = 40 degrees
  horizontal_flip = ImageDataGenerator(horizontal_flip=True,fill_mode='nearest')  # Flip images horizontally
  datagen = [rotate_datagen, horizontal_flip]
  aug_titles = ["Vertical flip Augmentation", "Horizontal flip Augmentation"]

  # Create a figure with two rows and two columns of subplots
  fig, axs = plt.subplots(2, 2, figsize=(10, 10))
  index = random.randint(0, len(X_train) - 1)  # Choose a random image index
  for i in range(2):
      augmented_image = datagen[i].random_transform(X_train[index])  # Augment a random image
      # Plot the original image
      axs[i, 0].imshow(X_train[index], cmap='gray')  # Force grayscale interpretation
      axs[i, 0].set_title("Original Image")
      axs[i, 0].axis('off')  # Remove axis numbering (ticks)
      # Plot the augmented image
      axs[i, 1].imshow(augmented_image, cmap='gray')  # Force grayscale interpretation
      axs[i, 1].set_title(aug_titles[i])
      axs[i, 1].axis('off')  # Remove axis numbering (ticks)
  plt.show()

# %% [markdown]
# # 3) Dataset

# %%
working_dir = 'C:\Skripsi/Enhancing-FER2013-Imbalance-main/Enhancing-FER2013-Imbalance-main/'

# %%
df = pd.read_csv(working_dir+'fer2013.csv')
print(df.head())
print(df.describe())
# Out:
#    emotion                                             pixels
# 0        0  46 34 26 23 12 32 35 26 26 38 71 99 123 134 14...
# 1        0  55 33 54 32 26 21 50 29 38 45 79 73 43 22 51 5...
# 2        0  123 123 126 131 124 69 109 149 159 174 169 178...
# 3        0  255 255 255 255 255 255 255 255 255 251 254 16...
# 4        0  127 121 124 137 123 118 120 111 111 109 118 14...
#             emotion
# count  35887.000000
# mean       3.323265
# std        1.873819
# min        0.000000
# 25%        2.000000
# 50%        3.000000
# 75%        5.000000
# max        6.000000

# %% [markdown]
# Visualisasi data dan label

# %%
emotion_map = {0:'anger', 1:'disgust', 2:'fear', 3:'happiness', 4: 'sadness', 5: 'surprise', 6: 'neutral'}
barplot(data=df,
        emotion_map=emotion_map,
        plt=plt,
        titleType='Emotions(Raw Data)')

del df

# %%
plotDatasetSamples(file_path=working_dir+'fer2013.csv',
                   emotion_map=emotion_map,
                   max_num_plot=15
                   )

# %% [markdown]
# # 4) Data Pre-processing
# **Langkah-langkah:**
# - Memisahkan dataset menjadi 3 bagian: Pelatihan: **80%**, Validasi: **10%**, dan Pengujian: **10%** (Bagian 3 dari `preProcess_augment_oversample()`)
# - Mengubah string menjadi daftar bilangan bulat: (Bagian 1 dari `preProcess_augment_oversample()`)
# - Mereshape menjadi 48x48x1 dan normalisasi gambar skala abu-abu: (Bagian 1 dari `preProcess_augment_oversample()`)
# - Melakukan enkoding one-hot label, misalnya kelas 3 menjadi [0,0,0,1,0,0,0]: (Bagian 4 dari `preProcess_augment_oversample()`)
# - Oversampling kelas minoritas: `preProcess_augment_oversample()`
# - Augmentasi data: `preProcess_augment_oversample()`

# %%
# Mengambil data dari file CSV
file_path = 'fer2013.csv'
data, labels = preProcess(file_path)

# Membagi data menjadi training, validation, dan testing sets
X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.25, random_state=42)

# Visualisasi distribusi data
barplot(data=pd.read_csv(file_path), emotion_map=emotion_map, plt=plt, titleType='Original Data')

# %% [markdown]
# # 5) CNN Architecture
#
#  - `create_CNN_model()`

# %%
model =create_CNN_model()
model.summary()
# Out:
# WARNING:tensorflow:From c:\Users\wilbe\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 48, 48, 32)        320
#
#  activation (Activation)     (None, 48, 48, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 46, 46, 64)        18496
#
#  activation_1 (Activation)   (None, 46, 46, 64)        0
#
#  average_pooling2d (Average  (None, 23, 23, 64)        0
#  Pooling2D)
#
#  dropout (Dropout)           (None, 23, 23, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 23, 23, 128)       73856
#
#  activation_2 (Activation)   (None, 23, 23, 128)       0
#
#  conv2d_3 (Conv2D)           (None, 21, 21, 128)       147584
#
#  activation_3 (Activation)   (None, 21, 21, 128)       0
#
#  average_pooling2d_1 (Avera  (None, 10, 10, 128)       0
#  gePooling2D)
#
#  dropout_1 (Dropout)         (None, 10, 10, 128)       0
#
#  flatten (Flatten)           (None, 12800)             0
#
#  dense (Dense)               (None, 128)               1638528
#
#  activation_4 (Activation)   (None, 128)               0
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 7)                 903
#
#  activation_5 (Activation)   (None, 7)                 0
#
# =================================================================
# Total params: 1879687 (7.17 MB)
# Trainable params: 1879687 (7.17 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # 6) Training

# %% [markdown]
# **Callbacks**
# - `ModelCheckpoint()`: Used to save best model weights during training process
# - `EarlyStopping()`:  Early stopping helps to stop training when model is no longer learning

# %%
current_time = datetime.datetime.now()
checkpoint_path = working_dir+f'checkpoint/best_model_experiment5_{str(current_time).split(" ")[0]}.h5'
checkpoint = ModelCheckpoint(checkpoint_path,
                             monitor='val_accuracy',
                             verbose=1,
                             save_best_only=True,
                             mode='max')  # 'max' if monitoring accuracy, 'min' if monitoring loss

early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# %% [markdown]
# **Compile dan Train Model**

# %%
model.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])
history = model.fit(X_train, y_train,
                    batch_size=32,
                    epochs=150,
                    validation_data=(X_val, y_val),
                    callbacks=[early_stop, checkpoint],
                    verbose=1,

                    )
# Out:
# Epoch 1/150
# 673/673 [==============================] - ETA: 0s - loss: 1.6239 - accuracy: 0.3753
# Epoch 1: val_accuracy improved from -inf to 0.39537, saving model to C:\Skripsi/Enhancing-FER2013-Imbalance-main/Enhancing-FER2013-Imbalance-main/checkpoint\best_model_experiment5_2024-06-27.h5
# 673/673 [==============================] - 57s 83ms/step - loss: 1.6239 - accuracy: 0.3753 - val_loss: 1.5573 - val_accuracy: 0.3954
# Epoch 2/150
# 673/673 [==============================] - ETA: 0s - loss: 1.5694 - accuracy: 0.3942
# Epoch 2: val_accuracy improved from 0.39537 to 0.41767, saving model to C:\Skripsi/Enhancing-FER2013-Imbalance-main/Enhancing-FER2013-Imbalance-main/checkpoint\best_model_experiment5_2024-06-27.h5
# 673/673 [==============================] - 57s 84ms/step - loss: 1.5694 - accuracy: 0.3942 - val_loss: 1.5181 - val_accuracy: 0.4177
# Epoch 3/150
# 673/673 [==============================] - ETA: 0s - loss: 1.5346 - accuracy: 0.4089
# Epoch 3: val_accuracy improved from 0.41767 to 0.43048, saving model to C:\Skripsi/Enhancing-FER2013-Imbalance-main/Enhancing-FER2013-Imbalance-main/checkpoint\best_model_experiment5_2024-06-27.h5
# 673/673 [==============================] - 57s 84ms/step - loss: 1.5346 - accuracy: 0.4089 - val_loss: 1.4647 - val_accuracy: 0.4305
# Epoch 4/150
# 673/673 [==============================] - ETA: 0s - loss: 1.4940 - accuracy: 0.4242
# Epoch 4: val_accuracy improved from 0.43048 to 0.43814, saving model to C:\Skripsi/Enhancing-FER2013-Imbalance-main/Enhancing-FER2013-Imbalance-main/checkpoint\best_model_experiment5_2024-06-27.h5
# 673/673 [==============================] - 56s 83ms/step - loss: 1.4940 - accuracy: 0.4242 - val_loss: 1.4319 - val_accuracy: 0.4381
# Epoch 5/150
# 673/673 [==============================] - ETA: 0s - loss: 1.4530 - accuracy: 0.4412
# Epoch 5: val_accuracy improved from 0.43814 to 0.45765, saving model to C:\Skripsi/Enhancing-FER2013-Imbalance-main/Enhancing-FER2013-Imbalance-main/checkpoint\best_model_experiment5_2024-06-27.h5
# 673/673 [==============================] - 56s 84ms/step - loss: 1.4530 - accuracy: 0.4412 - val_loss: 1.4055 - val_accuracy: 0.4576
# Epoch 6/150
# 673/673 [==============================] - ETA: 0s - loss: 1.4202 - accuracy: 0.4565
# Epoch 6: val_accuracy improved from 0.45765 to 0.47130, saving model to C:\Skripsi/Enhancing-FER2013-Imbalance-main/Enhancing-FER2013-Imbalance-main/checkpoint\best_model_experiment5_2024-06-27.h5
# 673/673 [==============================] - 56s 83ms/step - loss: 1.4202 - accuracy: 0.4565 - val_loss: 1.3806 - val_accuracy: 0.4713
# Epoch 7/150
# 673/673 [==============================] - ETA: 0s - loss: 1.3954 - accuracy: 0.4644
# Epoch 7: val_accuracy improved from 0.47130 to 0.47381, saving model to C:\Skripsi/Enhancing-FER2013-Imbalance-main/Enhancing-FER2013-Imbalance-main/checkpoint\best_model_experiment5_2024-06-27.h5
# 673/673 [==============================] - 56s 83ms/step - loss: 1.3954 - accuracy: 0.4644 - val_loss: 1.3565 - val_accuracy: 0.4738
# Epoch 8/150
# 673/673 [==============================] - ETA: 0s - loss: 1.3619 - accuracy: 0.4804
# Epoch 8: val_accuracy improved from 0.47381 to 0.48454, saving model to C:\Skripsi/Enhancing-FER2013-Imbalance-main/Enhancing-FER2013-Imbalance-main/checkpoint\best_model_experiment5_2024-06-27.h5
# 673/673 [==============================] - 56s 83ms/step - loss: 1.3619 - accuracy: 0.4804 - val_loss: 1.3390 - val_accuracy: 0.4845
# Epoch 9/150
# 673/673 [==============================] - ETA: 0s - loss: 1.3352 - accuracy: 0.4879
# Epoch 9: val_accuracy improved from 0.48454 to 0.48969, saving model to C:\Skripsi/Enhancing-FER2013-Imbalance-main/Enhancing-FER2013-Imbalance-main/checkpoint\best_model_experiment5_2024-06-27.h5
# 673/673 [==============================] - 56s 84ms/step - loss: 1.3352 - accuracy: 0.4879 - val_loss: 1.3264 - val_accuracy: 0.4897
# Epoch 10/150
# 673/673 [==============================] - ETA: 0s - loss: 1.3099 - accuracy: 0.4997
# Epoch 10: val_accuracy improved from 0.48969 to 0.49680, saving model to C:\Skripsi/Enhancing-FER2013-Imbalance-main/Enhancing-FER2013-Imbalance-main/checkpoint\best_model_experiment5_2024-06-27.h5
# 673/673 [==============================] - 56s 83ms/step - loss: 1.3099 - accuracy: 0.4997 - val_loss: 1.3051 - val_accuracy: 0.4968
# Epoch 11/150
# 673/673 [==============================] - ETA: 0s - loss: 1.2839 - accuracy: 0.5130
# Epoch 11: val_accuracy improved from 0.49680 to 0.50125, saving model to C:\Skripsi/Enhancing-FER2013-Imbalance-main/Enhancing-FER2013-Imbalance-main/checkpoint\best_model_experiment5_2024-06-27.h5
# 673/673 [==============================] - 57s 85ms/step - loss: 1.2839 - accuracy: 0.5130 - val_loss: 1.2869 - val_accuracy: 0.5013
# Epoch 12/150
# 673/673 [==============================] - ETA: 0s - loss: 1.2583 - accuracy: 0.5213
# Epoch 12: val_accuracy improved from 0.50125 to 0.50306, saving model to C:\Skripsi/Enhancing-FER2013-Imbalance-main/Enhancing-FER2013-Imbalance-main/checkpoint\best_model_experiment5_2024-06-27.h5
# 673/673 [==============================] - 61s 91ms/step - loss: 1.2583 - accuracy: 0.5213 - val_loss: 1.2903 - val_accuracy: 0.5031
# Epoch 13/150
# 673/673 [==============================] - ETA: 0s - loss: 1.2325 - accuracy: 0.5344
# Epoch 13: val_accuracy improved from 0.50306 to 0.50878, saving model to C:\Skripsi/Enhancing-FER2013-Imbalance-main/Enhancing-FER2013-Imbalance-main/checkpoint\best_model_experiment5_2024-06-27.h5
# 673/673 [==============================] - 62s 92ms/step - loss: 1.2325 - accuracy: 0.5344 - val_loss: 1.2827 - val_accuracy: 0.5088
# Epoch 14/150
# 673/673 [==============================] - ETA: 0s - loss: 1.2046 - accuracy: 0.5441
# Epoch 14: val_accuracy improved from 0.50878 to 0.51560, saving model to C:\Skripsi/Enhancing-FER2013-Imbalance-main/Enhancing-FER2013-Imbalance-main/checkpoint\best_model_experiment5_2024-06-27.h5
# 673/673 [==============================] - 91s 135ms/step - loss: 1.2046 - accuracy: 0.5441 - val_loss: 1.2641 - val_accuracy: 0.5156
# Epoch 15/150
# 673/673 [==============================] - ETA: 0s - loss: 1.1772 - accuracy: 0.5560
# Epoch 15: val_accuracy improved from 0.51560 to 0.51686, saving model to C:\Skripsi/Enhancing-FER2013-Imbalance-main/Enhancing-FER2013-Imbalance-main/checkpoint\best_model_experiment5_2024-06-27.h5
# 673/673 [==============================] - 109s 162ms/step - loss: 1.1772 - accuracy: 0.5560 - val_loss: 1.2539 - val_accuracy: 0.5169
# Epoch 16/150
# 673/673 [==============================] - ETA: 0s - loss: 1.1547 - accuracy: 0.5653
# Epoch 16: val_accuracy improved from 0.51686 to 0.51964, saving model to C:\Skripsi/Enhancing-FER2013-Imbalance-main/Enhancing-FER2013-Imbalance-main/checkpoint\best_model_experiment5_2024-06-27.h5
# 673/673 [==============================] - 109s 162ms/step - loss: 1.1547 - accuracy: 0.5653 - val_loss: 1.2446 - val_accuracy: 0.5196
# Epoch 17/150
# 673/673 [==============================] - ETA: 0s - loss: 1.1282 - accuracy: 0.5753
# Epoch 17: val_accuracy improved from 0.51964 to 0.52159, saving model to C:\Skripsi/Enhancing-FER2013-Imbalance-main/Enhancing-FER2013-Imbalance-main/checkpoint\best_model_experiment5_2024-06-27.h5
# 673/673 [==============================] - 106s 158ms/step - loss: 1.1282 - accuracy: 0.5753 - val_loss: 1.2684 - val_accuracy: 0.5216
# Epoch 18/150
# 673/673 [==============================] - ETA: 0s - loss: 1.1050 - accuracy: 0.5826
# Epoch 18: val_accuracy improved from 0.52159 to 0.53162, saving model to C:\Skripsi/Enhancing-FER2013-Imbalance-main/Enhancing-FER2013-Imbalance-main/checkpoint\best_model_experiment5_2024-06-27.h5
# 673/673 [==============================] - 107s 159ms/step - loss: 1.1050 - accuracy: 0.5826 - val_loss: 1.2371 - val_accuracy: 0.5316
# Epoch 19/150
# 673/673 [==============================] - ETA: 0s - loss: 1.0836 - accuracy: 0.5928
# Epoch 19: val_accuracy did not improve from 0.53162
# 673/673 [==============================] - 108s 160ms/step - loss: 1.0836 - accuracy: 0.5928 - val_loss: 1.2362 - val_accuracy: 0.5283
# Epoch 20/150
# 673/673 [==============================] - ETA: 0s - loss: 1.0526 - accuracy: 0.6055
# Epoch 20: val_accuracy improved from 0.53162 to 0.53385, saving model to C:\Skripsi/Enhancing-FER2013-Imbalance-main/Enhancing-FER2013-Imbalance-main/checkpoint\best_model_experiment5_2024-06-27.h5
# 673/673 [==============================] - 134s 200ms/step - loss: 1.0526 - accuracy: 0.6055 - val_loss: 1.2293 - val_accuracy: 0.5339
# Epoch 21/150
# 673/673 [==============================] - ETA: 0s - loss: 1.0275 - accuracy: 0.6060
# Epoch 21: val_accuracy improved from 0.53385 to 0.53775, saving model to C:\Skripsi/Enhancing-FER2013-Imbalance-main/Enhancing-FER2013-Imbalance-main/checkpoint\best_model_experiment5_2024-06-27.h5
# 673/673 [==============================] - 155s 231ms/step - loss: 1.0275 - accuracy: 0.6060 - val_loss: 1.2345 - val_accuracy: 0.5378
# Epoch 22/150
# 673/673 [==============================] - ETA: 0s - loss: 1.0073 - accuracy: 0.6163
# Epoch 22: val_accuracy did not improve from 0.53775
# 673/673 [==============================] - 155s 230ms/step - loss: 1.0073 - accuracy: 0.6163 - val_loss: 1.2290 - val_accuracy: 0.5373
# Epoch 23/150
# 673/673 [==============================] - ETA: 0s - loss: 0.9850 - accuracy: 0.6260
# Epoch 23: val_accuracy did not improve from 0.53775
# 673/673 [==============================] - 153s 227ms/step - loss: 0.9850 - accuracy: 0.6260 - val_loss: 1.2445 - val_accuracy: 0.5343
# Epoch 24/150
# 673/673 [==============================] - ETA: 0s - loss: 0.9579 - accuracy: 0.6317
# Epoch 24: val_accuracy did not improve from 0.53775
# 673/673 [==============================] - 152s 226ms/step - loss: 0.9579 - accuracy: 0.6317 - val_loss: 1.2394 - val_accuracy: 0.5362
# Epoch 25/150
# 673/673 [==============================] - ETA: 0s - loss: 0.9381 - accuracy: 0.6443
# Epoch 25: val_accuracy improved from 0.53775 to 0.53845, saving model to C:\Skripsi/Enhancing-FER2013-Imbalance-main/Enhancing-FER2013-Imbalance-main/checkpoint\best_model_experiment5_2024-06-27.h5
# 673/673 [==============================] - 155s 230ms/step - loss: 0.9381 - accuracy: 0.6443 - val_loss: 1.2406 - val_accuracy: 0.5385
# Epoch 26/150
# 673/673 [==============================] - ETA: 0s - loss: 0.9136 - accuracy: 0.6538
# Epoch 26: val_accuracy improved from 0.53845 to 0.54876, saving model to C:\Skripsi/Enhancing-FER2013-Imbalance-main/Enhancing-FER2013-Imbalance-main/checkpoint\best_model_experiment5_2024-06-27.h5
# 673/673 [==============================] - 153s 227ms/step - loss: 0.9136 - accuracy: 0.6538 - val_loss: 1.2362 - val_accuracy: 0.5488
# Epoch 27/150
# 673/673 [==============================] - ETA: 0s - loss: 0.8923 - accuracy: 0.6603
# Epoch 27: val_accuracy did not improve from 0.54876
# 673/673 [==============================] - 155s 230ms/step - loss: 0.8923 - accuracy: 0.6603 - val_loss: 1.2762 - val_accuracy: 0.5424
# Epoch 28/150
# 673/673 [==============================] - ETA: 0s - loss: 0.8680 - accuracy: 0.6670
# Epoch 28: val_accuracy did not improve from 0.54876
# 673/673 [==============================] - 180s 268ms/step - loss: 0.8680 - accuracy: 0.6670 - val_loss: 1.2668 - val_accuracy: 0.5432
# Epoch 29/150
# 673/673 [==============================] - ETA: 0s - loss: 0.8538 - accuracy: 0.6746
# Epoch 29: val_accuracy did not improve from 0.54876
# 673/673 [==============================] - 183s 272ms/step - loss: 0.8538 - accuracy: 0.6746 - val_loss: 1.2869 - val_accuracy: 0.5385
# Epoch 30/150
# 673/673 [==============================] - ETA: 0s - loss: 0.8323 - accuracy: 0.6806
# Epoch 30: val_accuracy did not improve from 0.54876
# 673/673 [==============================] - 182s 270ms/step - loss: 0.8323 - accuracy: 0.6806 - val_loss: 1.2690 - val_accuracy: 0.5467
# Epoch 31/150
# 673/673 [==============================] - ETA: 0s - loss: 0.8060 - accuracy: 0.6942
# Epoch 31: val_accuracy did not improve from 0.54876
# 673/673 [==============================] - 176s 261ms/step - loss: 0.8060 - accuracy: 0.6942 - val_loss: 1.2919 - val_accuracy: 0.5474
# Epoch 32/150
# 673/673 [==============================] - ETA: 0s - loss: 0.7862 - accuracy: 0.7001
# Epoch 32: val_accuracy did not improve from 0.54876
# 673/673 [==============================] - 153s 228ms/step - loss: 0.7862 - accuracy: 0.7001 - val_loss: 1.2759 - val_accuracy: 0.5488

# %% [markdown]
# **Save the training history dictionary**

# %%
history_path = working_dir+f'checkpoint/experiment5_best_model_history.pkl'

with open(history_path, 'wb') as file:
    pickle.dump(history.history, file)

# %% [markdown]
# **Visualisasi Performa Model**

# %%
plotModelHistory(history=history, plt=plt)

# %% [markdown]
# # 7) Test Model yang Sudah Dilatih

# %%
loss, accuracy = model.evaluate(X_test, y_test, verbose=1)
print('Test loss:', loss)
print('Test accuracy:', accuracy)
# Out:
# 225/225 [==============================] - 16s 69ms/step - loss: 1.2399 - accuracy: 0.5404
# Test loss: 1.2398768663406372
# Test accuracy: 0.5404012203216553

# %% [markdown]
# **Confusion Matrix**

# %%
plotConfusionMatrix(model=model,
                    X_test=X_test,
                    y_test=y_test,
                    emotion_map=emotion_map,
                    plt=plt,
                    np=np
                    )
# Out:
# 225/225 [==============================] - 17s 67ms/step

# %%
plotPredictions(X_test=X_test,
                y_test=y_test,
                model=model,
                plt=plt,
                emotion_map=emotion_map,
                max_num_plot = 15 )
# Out:
# 225/225 [==============================] - 16s 68ms/step
# Test Accuracy: 54.04%

# %% [markdown]
# # END
